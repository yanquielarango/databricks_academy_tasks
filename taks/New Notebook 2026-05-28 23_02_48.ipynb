# %% [markdown]
# # Init

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StryngType, IntegerType, DoubleType, StructType, StructField
from pyspark.sql.functions import trim, col
